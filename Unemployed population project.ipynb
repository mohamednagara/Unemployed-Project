# %% [markdown]
# # Unemployed population project

# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
# Load a CSV file into a DataFrame named df
df = pd.read_csv('unemployed_population_1978-12_to_2023-07.csv')

# Display the first few rows of the DataFrame
df.head()
# Out:
#          date  all  16-24  25-54  55-64  65+  less_than_hs  high_school  \
# 0  2023-07-01  3.6    7.8    3.1    2.4  2.7           7.0          4.8
# 1  2023-06-01  3.6    7.8    3.1    2.4  2.8           7.1          4.8
# 2  2023-05-01  3.6    7.9    3.0    2.4  2.8           7.1          4.8
# 3  2023-04-01  3.6    7.9    3.0    2.4  2.8           7.1          4.8
# 4  2023-03-01  3.6    8.0    3.0    2.5  2.8           7.1          4.8
#
#    some_college  bachelor's_degree  ...  white_men_16-24  white_men_25-54  \
# 0           3.4                2.4  ...              7.0              2.5
# 1           3.4                2.4  ...              7.0              2.5
# 2           3.4                2.4  ...              7.0              2.5
# 3           3.4                2.4  ...              7.0              2.5
# 4           3.5                2.4  ...              7.1              2.5
#
#    white_men_55-64  white_men_65+  white_men_less_than_hs  \
# ...

# %%
# Retrieve the shape or dimensions of the DataFrame 'df'
df.shape
# Out:
# (536, 122)

# %%
# Access the column names of the DataFrame 'df'
df.columns.to_list()
# Out:
# ['date',
#  'all',
#  '16-24',
#  '25-54',
#  '55-64',
#  '65+',
#  'less_than_hs',
#  'high_school',
#  'some_college',
#  "bachelor's_degree",
#  'advanced_degree',
#  'women',
#  'women_16-24',
#  'women_25-54',
#  'women_55-64',
#  'women_65+',
#  'women_less_than_hs',
#  'women_high_school',
#  'women_some_college',
#  "women_bachelor's_degree",
#  'women_advanced_degree',
#  'men',
#  'men_16-24',
#  'men_25-54',
#  'men_55-64',
#  'men_65+',
#  'men_less_than_hs',
#  'men_high_school',
#  'men_some_college',
#  "men_bachelor's_degree",
#  'men_advanced_degree',
#  'black',
#  'black_16-24',
#  'black_25-54',
#  'black_55-64',
#  'black_65+',
#  'black_less_than_hs',
#  'black_high_school',
#  'black_some_college',
#  "black_bachelor's_degree",
#  'black_advanced_degree',
#  'black_women',
#  'black_women_16-24',
#  'black_women_25-54',
#  'black_women_55-64',
#  'black_women_65+',
#  'black_women_less_than_hs',
#  'black_women_high_school',
#  'black_women_some_college',
# ...

# %% [markdown]
# # Heatmap to visualize missing data

# %%
# Import libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Create a figure with a custom size
plt.figure(figsize=(20, 10))

# Create a heatmap to visualize missing values in the 'df' DataFrame
sns.heatmap(df.isna(), cbar=False)

# Calculate the percentage of missing values for each column and sort them in ascending order
(df.isna().sum() / df.shape[0]).sort_values(ascending=True)
# Out:
# date                         0.0
# hispanic_men_some_college    0.0
# hispanic_men_high_school     0.0
# hispanic_men_less_than_hs    0.0
# hispanic_men_65+             0.0
#                             ...
# black_55-64                  0.0
# black_25-54                  0.0
# black_16-24                  0.0
# men_advanced_degree          0.0
# population_over_16           0.0
# Length: 122, dtype: float64

# %% [markdown]
# ### We can see that there is no missing data, which makes it easier for data cleaning.

# %%
# Generate a summary statistics report for the DataFrame 'df'
df.describe()
# Out:
#               all       16-24       25-54       55-64         65+  \
# count  536.000000  536.000000  536.000000  536.000000  536.000000
# mean     6.160261   12.558769    5.090672    3.972388    3.779291
# std      1.633552    2.596647    1.470262    1.191348    1.141110
# min      3.600000    7.800000    3.000000    2.400000    2.400000
# 25%      4.900000   10.800000    4.100000    3.100000    3.100000
# 50%      5.800000   12.100000    4.700000    3.700000    3.400000
# 75%      7.300000   14.000000    5.900000    4.600000    3.900000
# max     10.300000   18.700000    8.700000    7.300000    8.000000
#
#        less_than_hs  high_school  some_college  bachelor's_degree  \
# count    536.000000   536.000000    536.000000         536.000000
# mean      12.366978     6.896455      5.350373           3.225000
# std        2.738656     1.918958      1.538527           0.923954
# min        7.000000     4.300000      3.100000           1.900000
# ...

# %%
# Drop the 'population_over_16' column from the DataFrame 'df'
df = df.drop(['population_over_16'], axis=1)

# %% [markdown]
# # Ranking of categories of individuals displaying the lowest unemployment rate by %

# %%
# Calculate the means for each column
moyennes = df.mean()

# Sort the means in ascending order
moyennes = moyennes.sort_values(ascending=True)

# Display the means with all rows and columns visible
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(moyennes)
# Out:
# white_men_advanced_degree            1.921082
# white_advanced_degree                2.054291
# men_advanced_degree                  2.085821
# advanced_degree                      2.239179
# white_women_advanced_degree          2.322388
# women_advanced_degree                2.521269
# white_men_bachelor's_degree          2.828358
# white_bachelor's_degree              2.905037
# hispanic_men_advanced_degree         2.910821
# hispanic_advanced_degree             3.011381
# white_women_bachelor's_degree        3.020709
# black_women_advanced_degree          3.091978
# men_bachelor's_degree                3.127425
# bachelor's_degree                    3.225000
# hispanic_women_advanced_degree       3.225373
# white_men_65+                        3.301679
# white_women_55-64                    3.342164
# women_bachelor's_degree              3.360261
# black_advanced_degree                3.363619
# white_65+                            3.383396
# ...

# %% [markdown]
# ### One can observe that white individuals with higher levels of qualifications have a lower probability of becoming unemployed, whereas black individuals without a diploma have an unemployment rate of 25%, which amounts to one in four people.

# %% [markdown]
# # Transformation of the index involving the permutation of the variable "year" into the index, in order to facilitate analyses for each year.

# %%
import pandas as pd

# First, convert the "date" variable to a datetime object
df['date'] = pd.to_datetime(df['date'])

# Extract the year from the "date" variable
df['year'] = df['date'].dt.year

# Group the data by year and calculate the mean for each group
yearly_averages = df.groupby('year').mean()

# If you want to reset the index to make "year" a regular column:
yearly_averages = yearly_averages.reset_index()

# Print the resulting DataFrame
print(yearly_averages)
# Out:
#     year        all      16-24     25-54     55-64       65+  less_than_hs  \
# 0   1978   6.100000  12.400000  4.300000  2.900000  3.800000     10.000000
# 1   1979   5.908333  11.950000  4.225000  2.808333  3.566667      9.925000
# 2   1980   6.533333  13.008333  4.825000  3.016667  3.066667     11.150000
# 3   1981   7.550000  14.733333  5.775000  3.591667  2.983333     12.975000
# 4   1982   8.691667  16.541667  6.866667  4.525000  3.250000     15.108333
# 5   1983  10.083333  18.091667  8.391667  5.683333  3.608333     17.475000
# 6   1984   8.358333  15.333333  6.825000  4.916667  3.375000     15.166667
# 7   1985   7.308333  13.700000  5.925000  4.383333  3.091667     13.891667
# 8   1986   7.058333  13.475000  5.733333  4.158333  3.066667     13.583333
# 9   1987   6.625000  12.850000  5.408333  3.725000  2.683333     13.041667
# 10  1988   5.766667  11.558333  4.683333  3.316667  2.500000     11.625000
# ...

# %%
# Convert 'df' to a pandas DataFrame
df = pd.DataFrame(df)

# Set the 'year' column as the index
df.set_index('year', inplace=True)

# %%
df.head()
# Out:
#            date  all  16-24  25-54  55-64  65+  less_than_hs  high_school  \
# year
# 2023 2023-07-01  3.6    7.8    3.1    2.4  2.7           7.0          4.8
# 2023 2023-06-01  3.6    7.8    3.1    2.4  2.8           7.1          4.8
# 2023 2023-05-01  3.6    7.9    3.0    2.4  2.8           7.1          4.8
# 2023 2023-04-01  3.6    7.9    3.0    2.4  2.8           7.1          4.8
# 2023 2023-03-01  3.6    8.0    3.0    2.5  2.8           7.1          4.8
#
#       some_college  bachelor's_degree  ...  \
# year                                   ...
# 2023           3.4                2.4  ...
# 2023           3.4                2.4  ...
# 2023           3.4                2.4  ...
# 2023           3.4                2.4  ...
# 2023           3.5                2.4  ...
#
#       white_men_moyenne_annuelle_moyenne_annuelle_yearly_average  \
# year
# 2023                                           2.942857
# 2023                                           2.942857
# ...

# %%
df.drop(['date'],axis=1)
# Out:
#       all  16-24  25-54  55-64  65+  less_than_hs  high_school  some_college  \
# year
# 2023  3.6    7.8    3.1    2.4  2.7           7.0          4.8           3.4
# 2023  3.6    7.8    3.1    2.4  2.8           7.1          4.8           3.4
# 2023  3.6    7.9    3.0    2.4  2.8           7.1          4.8           3.4
# 2023  3.6    7.9    3.0    2.4  2.8           7.1          4.8           3.4
# 2023  3.6    8.0    3.0    2.5  2.8           7.1          4.8           3.5
# ...   ...    ...    ...    ...  ...           ...          ...           ...
# 1979  5.9   11.9    4.2    2.8  3.7           9.9          5.4           4.9
# 1979  6.0   12.0    4.3    2.8  3.8           9.9          5.4           4.9
# 1979  6.0   12.2    4.3    2.8  3.8           9.9          5.4           5.0
# 1979  6.1   12.3    4.3    2.9  3.7          10.0          5.5           5.0
# 1978  6.1   12.4    4.3    2.9  3.8          10.0          5.5           5.0
#
# ...

# %%
import pandas as pd

# convert the "date" variable to a datetime object.
df['date'] = pd.to_datetime(df['date'])

# Extract the year from the "date" variable.
df['year'] = df['date'].dt.year

# %%
# Group the data by year and calculate the mean for each group.
annual_means = df.groupby('year').mean()
# Reset the index so that "year" becomes a regular column.
annual_means = annual_means.reset_index()

# %%
# Replace your original DataFrame with the annual means DataFrame.
df = annual_means

# Display the resulting DataFrame containing annual means.
print(df)

# %%
df.head()
# Out:
#    année       all      16-24     25-54     55-64       65+  less_than_hs  \
# 0   1978  6.100000  12.400000  4.300000  2.900000  3.800000     10.000000
# 1   1979  5.908333  11.950000  4.225000  2.808333  3.566667      9.925000
# 2   1980  6.533333  13.008333  4.825000  3.016667  3.066667     11.150000
# 3   1981  7.550000  14.733333  5.775000  3.591667  2.983333     12.975000
# 4   1982  8.691667  16.541667  6.866667  4.525000  3.250000     15.108333
#
#    high_school  some_college  bachelor's_degree  ...  \
# 0     5.500000      5.000000           3.100000  ...
# 1     5.366667      4.808333           2.925000  ...
# 2     6.216667      5.283333           2.808333  ...
# 3     7.450000      6.066667           3.066667  ...
# 4     8.875000      6.900000           3.550000  ...
#
#    white_men_moyenne_annuelle_moyenne_annuelle_yearly_average  \
# 0                                           4.400000
# 1                                           4.233333
# ...

# %%
# Set the index of the DataFrame 'df' to the 'année' column
df = df.set_index('année')

# %%
df.head()
# Out:
#             all      16-24     25-54     55-64       65+  less_than_hs  \
# année
# 1978   6.100000  12.400000  4.300000  2.900000  3.800000     10.000000
# 1979   5.908333  11.950000  4.225000  2.808333  3.566667      9.925000
# 1980   6.533333  13.008333  4.825000  3.016667  3.066667     11.150000
# 1981   7.550000  14.733333  5.775000  3.591667  2.983333     12.975000
# 1982   8.691667  16.541667  6.866667  4.525000  3.250000     15.108333
#
#        high_school  some_college  bachelor's_degree  advanced_degree  ...  \
# année                                                                 ...
# 1978      5.500000      5.000000           3.100000         2.000000  ...
# 1979      5.366667      4.808333           2.925000         1.933333  ...
# 1980      6.216667      5.283333           2.808333         1.841667  ...
# 1981      7.450000      6.066667           3.066667         2.008333  ...
# 1982      8.875000      6.900000           3.550000         2.383333  ...
#
# ...

# %% [markdown]
# # A graph comparing unemployment rates among white, black, and Hispanic ethnic groups in order to assess their respective unemployment rates.

# %%
# Import necessary libraries
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(20, 12))

# Plot the data for different ethnicities
plt.plot(df.index, df['black'], label='Black')
plt.plot(df.index, df['hispanic'], label='Hispanic')
plt.plot(df.index, df['white'], label='White')

# Set the x and y-axis labels
plt.xlabel("Year")
plt.ylabel("Unemployment Rate")
plt.title("Unemployment Rate by Ethnicity")

# Add a legend to distinguish between ethnicities
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
#  One can observe that, regardless of the year, Black individuals in the United States experience higher unemployment rates compared to Hispanic and White individuals, and this disparity persists even 40 years later. This observation is partly explained by deeply rooted socio-economic and historical factors. For instance, the legacy of racial segregation in the United States has resulted in enduring inequalities in education, employment opportunities, and economic mobility for African-American communities. Furthermore, racial stereotypes and biases can influence recruitment and promotion practices, disadvantaging Black individuals in the labor market. Consequently, despite the social and legal progress made over the decades, unemployment disparities persist, significantly impacting the economic prospects of African-Americans in the United States.

# %% [markdown]
# # A graph comparing the unemployment rates among white, black, and Hispanic women, with the aim of comparing their respective unemployment rates by ethnicity.

# %%
# Import necessary libraries
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(20, 10))

# Plot the data for different ethnicities among women
plt.plot(df.index, df['black_women'], label='Black Women')
plt.plot(df.index, df['hispanic_women'], label='Hispanic Women')
plt.plot(df.index, df['white_women'], label='White Women')

# Set the x and y-axis labels
plt.xlabel('Year')
plt.ylabel('Unemployment Rate')
plt.title("Unemployment Rate by Ethnicity Among Women")

# Add a legend to distinguish between ethnicities among women
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# This graph highlights the persistence of ethnic disparities in unemployment in the United States. The higher unemployment rates among Black individuals reflect deeply ingrained historical inequalities, particularly regarding access to education, economic opportunities, and support systems. For example, the long history of racial discrimination, including segregation, has left lasting effects that continue to impact the professional prospects of African Americans.
#
# The occasional increase in unemployment rates among Hispanic women, as observed in 1995 and 2022, can be attributed to various economic and social factors, including cyclical fluctuations in the economy, changes in the composition of the workforce, and specific economic policies. For instance, an economic recession or fluctuations in the industrial sector can disproportionately affect certain ethnic groups.
#
# Therefore, while Black women consistently exhibit higher average unemployment rates, these occasional fluctuations among Hispanic women illustrate the complexity of the factors influencing the labor market and underscore the need to consider historical and situational factors when analyzing unemployment data in the United States.

# %% [markdown]
# # A graph comparing the unemployment rates among white, black, and Hispanic men, with the aim of comparing their respective unemployment rates by ethnicity.

# %%
# Import necessary libraries
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(20, 10)

# Plot the data for different ethnicities among men
plt.plot(df.index, df['black_men'], label='Black Men')
plt.plot(df.index, df['hispanic_men'], label='Hispanic Men')
plt.plot(df.index, df['white_men'], label='White Men')

# Set the x and y-axis labels
plt.xlabel('Year')
plt.ylabel('Unemployment Rate')
plt.title("Unemployment Rate by Ethnicity Among Men")

# Add a legend to distinguish between ethnicities among men
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# In this analysis, it is evident that Black men are the most severely affected by unemployment, followed by Hispanic men and White men. This observation reveals significant employment disparities, which are often linked to deep-seated socio-economic and historical factors. For instance, systemic racial discrimination, unequal access to education, and disparities in economic opportunities are factors contributing to these differences in unemployment rates. Recognizing and understanding these inequalities is essential for crafting policies and measures aimed at reducing employment disparities.

# %% [markdown]
# # A graph depicting unemployment rates by gender.

# %%
# Import necessary libraries
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(20, 10))

# Plot the data for different genders
plt.plot(df.index, df['men'], label='Men')
plt.plot(df.index, df['women'], label='Women')

# Set the x and y-axis labels
plt.xlabel('Year')
plt.ylabel('Unemployment Rate')
plt.title('Unemployment Rate by Gender')

# Add a legend to distinguish between genders
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# This observation regarding gender highlights that men are the most affected by unemployment, with several peaks, notably in 1985, 1994, 2005, and 2010. This trend can be explained by various socio-economic factors in the United States. For example, during these years, major economic crises, such as the 2008 recession, disproportionately impacted male employment, especially in sectors like construction and finance.
#
# Apart from these peaks, unemployment rates remain relatively similar throughout our study, indicating a degree of stability. However, it is essential to note that even during periods of stability, gender disparities in the labor market may persist. Wage gaps, differences in the types of jobs held by men and women, and other structural factors can contribute to maintaining these differences in unemployment rates. A thorough analysis of this data can help in developing policies aimed at reducing these inequalities and promoting gender equality in the job market.

# %% [markdown]
# # Unemployment rates by age category.

# %%
# Import necessary libraries
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(20, 10))

# Plot the data for different age groups
plt.plot(df.index, df['16-24'], label='16-24')
plt.plot(df.index, df['25-54'], label='25-54')
plt.plot(df.index, df['55-64'], label='55-64')
plt.plot(df.index, df['65+'], label='65+')

# Set the x and y-axis labels
plt.xlabel('Year')
plt.ylabel('Unemployment Rate')
plt.title("Unemployment Rate by Age Group")

# Add a legend to distinguish between age groups
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# The individuals most affected by unemployment in the United States are consistently young people aged 16 to 24, regardless of the year. This significant gap results in a difference of up to 10 percentage points compared to other age groups. This situation highlights the unique challenges that young people face in the job market. For example, students seeking part-time employment while continuing their studies may be more vulnerable to economic fluctuations and recruitment difficulties.
#
# As for the other age groups, the unemployment rate remains relatively similar. This suggests that employment trends are more stable for older individuals, who may have acquired more robust professional experience and are less likely to enter and exit the labor market frequently. Nevertheless, this substantial disparity between young people and other age groups underscores the importance of providing specific job and training opportunities for young individuals to reduce these gaps and facilitate their successful entry into the labor market.

# %% [markdown]
# # Unemployment rates by educational attainment.

# %%
# Import necessary libraries
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(20, 10))

# Plot the data for different levels of education
plt.plot(df.index, df['less_than_hs'], label='Less than High School')
plt.plot(df.index, df['high_school'], label='High School')
plt.plot(df.index, df['some_college'], label='Some College')
plt.plot(df.index, df["bachelor's_degree"], label="Bachelor's Degree")
plt.plot(df.index, df['advanced_degree'], label='Advanced Degree')

# Set the x and y-axis labels
plt.xlabel('Year')
plt.ylabel('Unemployment Rate')
plt title("Unemployment Rate by Education Level")

# Add a legend to distinguish between education levels
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# We can observe from this graph that logically, the less educated individuals are, the more they are affected by unemployment. This relationship between education level and unemployment is well-established and reflects a consistent trend in the United States. For instance, individuals with a college degree tend to have a lower unemployment rate compared to those with only a high school diploma or who have not completed their education.
#
# This disparity can be explained by the fact that highly skilled and well-paying jobs are often accessible to those with a higher level of education, while less qualified or precarious jobs are more common among less educated individuals. Therefore, investing in education and training can play a crucial role in reducing unemployment rates and improving job prospects. This observation underscores the importance of educational policies aimed at promoting skill acquisition and reducing inequalities in the labor market.
